# %% [markdown]
# # Multi-energy multimode phase retrieval
# Minimal use of `phase_retrieval_core_multienergy_multimode.py`.

# %%
import numpy as np
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import sys, os
from os.path import join
sys.path.append("/home/user/Moritz/msc/RB2004/code/FTH-Phase_Retrieval/library")
import phase_retrieval_core_multienergy as phr_me
import phase_retrieval_core_multienergy_multimode as pr

# %%
data = np.load(Path("/home/user/Moritz/msc/RB2004/data.npz"))
holograms = data["holograms"]
energy_ev = data["energy"]
mask_pixel = data["mask_pixel"]
supportmask = np.load("/home/user/Moritz/msc/RB2004/suppmask.npz.npy")

optical_constants = np.load(Path("/home/user/Moritz/msc/RB2004/data/refractive_index_constraints.npz"))
constraint_energy_ev = optical_constants["energy_ev"]
beta = optical_constants["beta"]
delta = optical_constants["delta"]

#if not np.allclose(energy_ev, constraint_energy_ev):
beta = np.interp(energy_ev, constraint_energy_ev, beta)
delta = np.interp(energy_ev, constraint_energy_ev, delta)

assert holograms.shape[0] == energy_ev.size == beta.size == delta.size
assert supportmask.shape == holograms.shape[1:]

# %%
bin_factor = 2
support_crop_pad = bin_factor
supportmask = np.load("/home/user/Moritz/msc/RB2004/suppmask.npz.npy")


def _bin_2d(array, factor, reducer="mean"):
    array = np.asarray(array)
    if array.ndim != 2:
        raise ValueError("Expected a 2D array.")
    if factor <= 0:
        raise ValueError("bin_factor must be a positive integer.")

    height, width = array.shape
    trimmed_height = height - (height % factor)
    trimmed_width = width - (width % factor)
    array = array[:trimmed_height, :trimmed_width]
    reshaped = array.reshape(
        trimmed_height // factor,
        factor,
        trimmed_width // factor,
        factor,
    )

    if reducer == "mean":
        return reshaped.mean(axis=(1, 3))
    if reducer == "max":
        return reshaped.max(axis=(1, 3))
    raise ValueError("reducer must be 'mean' or 'max'.")


def _bin_stack(stack, factor, reducer="mean"):
    stack = np.asarray(stack)
    if stack.ndim == 2:
        return _bin_2d(stack, factor, reducer=reducer)
    if stack.ndim != 3:
        raise ValueError("Expected a 2D image or 3D energy stack.")
    return np.stack([
        _bin_2d(image, factor, reducer=reducer) for image in stack
    ])


def _support_crop_slices(supportmask, pad, factor):
    supportmask = np.asarray(supportmask)
    support_pixels = np.argwhere(supportmask > 0)
    if not support_pixels.size:
        return (slice(None), slice(None))

    row_min, col_min = support_pixels.min(axis=0)
    row_max, col_max = support_pixels.max(axis=0) + 1
    height, width = supportmask.shape

    row_min = max(0, row_min - pad)
    col_min = max(0, col_min - pad)
    row_max = min(height, row_max + pad)
    col_max = min(width, col_max + pad)

    c0, c1 = (row_min + row_max) /2, (col_min + col_max) /2

    return c0, c1


c0, c1 = _support_crop_slices(
    np.load("/home/user/Moritz/msc/RB2004/suppmask.npz.npy"),
    support_crop_pad,
    bin_factor,
)


def center_and_crop(img, c0, c1, frac=0.5):
    center0, center1 = img.shape[0] // 2, img.shape[1] // 2
    shift0, shift1 = int(center0 - np.round(c0)), int(center1 - np.round(c1))
    shifted = np.roll(img, (shift0, shift1), axis=(0, 1))

    h = int(img.shape[0] * frac)//2
    w = int(img.shape[1] * frac)//2
    
    return shifted[(img.shape[0] // 2) -h:(img.shape[0] // 2) + h, (img.shape[1] // 2) - w:(img.shape[1] // 2) + w]

# %%
supportmask = center_and_crop(supportmask, c0, c1, frac=0.5)

holograms = _bin_stack(
    data["holograms"],
    bin_factor,
    reducer="mean",
)
mask_pixel = _bin_stack(
    data["mask_pixel"],
    bin_factor,
    reducer="max",
)

supportmask = (supportmask > 0).astype(supportmask.dtype)

assert holograms.shape[0] == energy_ev.size == beta.size == delta.size
assert supportmask.shape == holograms.shape[1:]
assert mask_pixel.shape == holograms.shape

# %%
supportmask.shape
# Out:
# (550, 550)

# %%
holograms[0].shape
# Out:
# (550, 550)

# %%
from interactive import cimshow
# %matplotlib widget
cimshow(holograms)
# Out:
# interactive(children=(FloatRangeSlider(value=(9.491102234684877, 81410.19737861928), description='contrast', l…
# interactive(children=(IntSlider(value=0, description='nr', max=14), Output()), _dom_classes=('widget-interact'…
# (<Figure size 700x700 with 1 Axes>, <Axes: >)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import cupy as cp
import numpy as np

if not hasattr(cp, 'errstate'):
    cp.errstate = np.errstate

# %%
recipe = {
    # Per-energy multimode update schedule.
    "inner_mode": ["HAPRE", "ER"],       # Algorithm stages at every energy.
    "inner_Nit": [700, 50],               # Iterations in each stage.
    "outer_iterations": 10,              # Number of update-plus-projection cycles.
    "warmup_mode": ["HAPRE", "ER"],      # Independent pre-coupling stages.
    "warmup_Nit": 0,                      # Zero disables warmup.
    "shuffle_energies": True,             # Randomize energy order each outer cycle.
    "random_seed": None,                  # Seed for energy-order randomization.
    "beta_zero": 0.5,                     # Beta value(s), broadcast or one per stage.
    "beta_mode": "arctan",               # Beta schedule name(s) or arrays.
    "alpha_zero": 0.0,                    # TV strength; zero disables TV.
    "alpha_mode": "const",               # Alpha schedule name(s) or arrays.
    "TV_freq": 1e9,                       # TV update interval.
    "warmup_beta_zero": None,             # None inherits the inner setting.
    "warmup_beta_mode": None,             # None inherits the inner setting.
    "warmup_alpha_zero": None,            # None inherits the inner setting.
    "warmup_alpha_mode": None,            # None inherits the inner setting.
    "warmup_TV_freq": None,               # None inherits the inner setting.
    "plot_every": 1e9,                    # Error sampling/plot interval.
    "average_img": 1,                     # Number of best late iterates to average.
    "Fourier_last": True,                 # Finish each stage with its Fourier constraint.
    "final_fourier_constraint": True,     # Enforce measured summed modal intensity at the end.
    "hologram_intensity_cutoff_vmin": -1, # Percentile baseline subtraction.
    # Cross-energy projection applied independently to every mode.
    "projection_model": "rank1_spectral",           # "none", "svd", or "rank1_spectral".
    "rank": 1,                            # SVD residual rank.
    "projection_every": 6,                # Projection interval in outer cycles.
    "projection_relaxation": 1.0,         # Projection blending fraction.
    "projection_constraints_inside_support_only": False, # If True, apply joint projections only inside supportmask.
    "projection_start": 0,                # First cycle eligible for projection.
    "projection_static_mode": "mean",    # "mean", "first", or "none".
    "energy_weights": None,               # Positive weight per energy.
    "log_floor": 1e-12,                   # Magnitude floor before complex log.
    "spectral_constraint": "known_beta",       # Rank-one spectrum: free, KK, or known-beta modes.
    "energy_values": None,                # Strictly increasing energies for KK constraints.
    "known_beta_spectrum": beta,          # Known absorption-like spectrum.
    "known_delta_spectrum": None,         # Optional known dispersion-like spectrum.
    "absorption_part": "real",           # Absorption location in the complex coefficient.
    "kk_sign": 1.0,                       # KK sign convention.
    "kk_subtract_baseline": True,         # Remove endpoint baseline before KK.
    "kk_normalize_input": False,          # Normalize absorption before KK.
    "known_beta_normalization": "none",  # none, maxabs, l2, or std.
    "fit_known_beta_scale": True,         # Fit known-spectrum scale.
    "fit_known_beta_offset": True,        # Fit known-spectrum offset.
    # Shared Richardson-Lucy controls.
    "RL_it": 0,                           # Partial-coherence iterations.
    "RL_freq": 1e9,                       # Partial-coherence update interval.
    # Multimode-only controls.
    "Nmodes": 1,                          # Number of mutually incoherent modes per energy.
    "mode_initialization_seed": 0,        # Seed used to break initial modal degeneracy.
}

fields, components, bsmasks, errors = (
    pr.multi_energy_phase_retrieval_algorithm(
        holograms,
        mask_pixel,
        supportmask,
        multi_energy_recipe=recipe,
    )
)
# Out:
# Outer 0: completed update 1 for energy 3 (no projection due)
# Outer 0: completed update 2 for energy 11 (no projection due)
# Outer 0: completed update 3 for energy 6 (no projection due)
# Outer 0: completed update 4 for energy 12 (no projection due)
# Outer 0: completed update 5 for energy 14 (no projection due)
# Outer 0: projection applied after update 6 for energy 4 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 0: completed update 7 for energy 5 (no projection due)
# Outer 0: completed update 8 for energy 0 (no projection due)
# Outer 0: completed update 9 for energy 10 (no projection due)
# Outer 0: completed update 10 for energy 8 (no projection due)
# Outer 0: completed update 11 for energy 7 (no projection due)
# Outer 0: projection applied after update 12 for energy 2 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 0: completed update 13 for energy 13 (no projection due)
# Outer 0: completed update 14 for energy 1 (no projection due)
# Outer 0: completed update 15 for energy 9 (no projection due)
# Outer 1: completed update 16 for energy 3 (no projection due)
# Outer 1: completed update 17 for energy 5 (no projection due)
# Outer 1: projection applied after update 18 for energy 7 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 1: completed update 19 for energy 10 (no projection due)
# Outer 1: completed update 20 for energy 13 (no projection due)
# Outer 1: completed update 21 for energy 6 (no projection due)
# Outer 1: completed update 22 for energy 8 (no projection due)
# Outer 1: completed update 23 for energy 0 (no projection due)
# Outer 1: projection applied after update 24 for energy 11 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 1: completed update 25 for energy 1 (no projection due)
# Outer 1: completed update 26 for energy 4 (no projection due)
# Outer 1: completed update 27 for energy 14 (no projection due)
# Outer 1: completed update 28 for energy 2 (no projection due)
# Outer 1: completed update 29 for energy 12 (no projection due)
# Outer 1: projection applied after update 30 for energy 9 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 2: completed update 31 for energy 11 (no projection due)
# Outer 2: completed update 32 for energy 4 (no projection due)
# Outer 2: completed update 33 for energy 12 (no projection due)
# Outer 2: completed update 34 for energy 13 (no projection due)
# Outer 2: completed update 35 for energy 5 (no projection due)
# Outer 2: projection applied after update 36 for energy 1 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 2: completed update 37 for energy 10 (no projection due)
# Outer 2: completed update 38 for energy 0 (no projection due)
# Outer 2: completed update 39 for energy 7 (no projection due)
# Outer 2: completed update 40 for energy 9 (no projection due)
# Outer 2: completed update 41 for energy 6 (no projection due)
# Outer 2: projection applied after update 42 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 2: completed update 43 for energy 2 (no projection due)
# Outer 2: completed update 44 for energy 3 (no projection due)
# Outer 2: completed update 45 for energy 14 (no projection due)
# Outer 3: completed update 46 for energy 6 (no projection due)
# Outer 3: completed update 47 for energy 14 (no projection due)
# Outer 3: projection applied after update 48 for energy 9 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 3: completed update 49 for energy 4 (no projection due)
# Outer 3: completed update 50 for energy 12 (no projection due)
# Outer 3: completed update 51 for energy 13 (no projection due)
# Outer 3: completed update 52 for energy 10 (no projection due)
# Outer 3: completed update 53 for energy 5 (no projection due)
# Outer 3: projection applied after update 54 for energy 0 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 3: completed update 55 for energy 2 (no projection due)
# Outer 3: completed update 56 for energy 7 (no projection due)
# Outer 3: completed update 57 for energy 8 (no projection due)
# Outer 3: completed update 58 for energy 1 (no projection due)
# Outer 3: completed update 59 for energy 3 (no projection due)
# Outer 3: projection applied after update 60 for energy 11 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 4: completed update 61 for energy 14 (no projection due)
# Outer 4: completed update 62 for energy 12 (no projection due)
# Outer 4: completed update 63 for energy 6 (no projection due)
# Outer 4: completed update 64 for energy 11 (no projection due)
# Outer 4: completed update 65 for energy 13 (no projection due)
# Outer 4: projection applied after update 66 for energy 5 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 4: completed update 67 for energy 10 (no projection due)
# Outer 4: completed update 68 for energy 1 (no projection due)
# Outer 4: completed update 69 for energy 0 (no projection due)
# Outer 4: completed update 70 for energy 9 (no projection due)
# Outer 4: completed update 71 for energy 3 (no projection due)
# Outer 4: projection applied after update 72 for energy 4 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 4: completed update 73 for energy 7 (no projection due)
# Outer 4: completed update 74 for energy 2 (no projection due)
# Outer 4: completed update 75 for energy 8 (no projection due)
# Outer 5: completed update 76 for energy 1 (no projection due)
# Outer 5: completed update 77 for energy 4 (no projection due)
# Outer 5: projection applied after update 78 for energy 7 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 5: completed update 79 for energy 0 (no projection due)
# Outer 5: completed update 80 for energy 10 (no projection due)
# Outer 5: completed update 81 for energy 5 (no projection due)
# Outer 5: completed update 82 for energy 2 (no projection due)
# Outer 5: completed update 83 for energy 13 (no projection due)
# Outer 5: projection applied after update 84 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 5: completed update 85 for energy 14 (no projection due)
# Outer 5: completed update 86 for energy 12 (no projection due)
# Outer 5: completed update 87 for energy 11 (no projection due)
# Outer 5: completed update 88 for energy 6 (no projection due)
# Outer 5: completed update 89 for energy 9 (no projection due)
# Outer 5: projection applied after update 90 for energy 3 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 6: completed update 91 for energy 12 (no projection due)
# Outer 6: completed update 92 for energy 4 (no projection due)
# Outer 6: completed update 93 for energy 2 (no projection due)
# Outer 6: completed update 94 for energy 9 (no projection due)
# Outer 6: completed update 95 for energy 1 (no projection due)
# Outer 6: projection applied after update 96 for energy 10 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 6: completed update 97 for energy 6 (no projection due)
# Outer 6: completed update 98 for energy 0 (no projection due)
# Outer 6: completed update 99 for energy 14 (no projection due)
# Outer 6: completed update 100 for energy 7 (no projection due)
# Outer 6: completed update 101 for energy 11 (no projection due)
# Outer 6: projection applied after update 102 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 6: completed update 103 for energy 13 (no projection due)
# Outer 6: completed update 104 for energy 3 (no projection due)
# Outer 6: completed update 105 for energy 5 (no projection due)
# Outer 7: completed update 106 for energy 12 (no projection due)
# Outer 7: completed update 107 for energy 2 (no projection due)
# Outer 7: projection applied after update 108 for energy 5 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 7: completed update 109 for energy 8 (no projection due)
# Outer 7: completed update 110 for energy 9 (no projection due)
# Outer 7: completed update 111 for energy 6 (no projection due)
# Outer 7: completed update 112 for energy 3 (no projection due)
# Outer 7: completed update 113 for energy 13 (no projection due)
# Outer 7: projection applied after update 114 for energy 14 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 7: completed update 115 for energy 1 (no projection due)
# Outer 7: completed update 116 for energy 10 (no projection due)
# Outer 7: completed update 117 for energy 7 (no projection due)
# Outer 7: completed update 118 for energy 11 (no projection due)
# Outer 7: completed update 119 for energy 0 (no projection due)
# Outer 7: projection applied after update 120 for energy 4 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 8: completed update 121 for energy 6 (no projection due)
# Outer 8: completed update 122 for energy 1 (no projection due)
# Outer 8: completed update 123 for energy 7 (no projection due)
# Outer 8: completed update 124 for energy 14 (no projection due)
# Outer 8: completed update 125 for energy 10 (no projection due)
# Outer 8: projection applied after update 126 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 8: completed update 127 for energy 9 (no projection due)
# Outer 8: completed update 128 for energy 11 (no projection due)
# Outer 8: completed update 129 for energy 13 (no projection due)
# Outer 8: completed update 130 for energy 0 (no projection due)
# Outer 8: completed update 131 for energy 12 (no projection due)
# Outer 8: projection applied after update 132 for energy 5 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 8: completed update 133 for energy 3 (no projection due)
# Outer 8: completed update 134 for energy 4 (no projection due)
# Outer 8: completed update 135 for energy 2 (no projection due)
# Outer 9: completed update 136 for energy 5 (no projection due)
# Outer 9: completed update 137 for energy 4 (no projection due)
# Outer 9: projection applied after update 138 for energy 13 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 9: completed update 139 for energy 14 (no projection due)
# Outer 9: completed update 140 for energy 7 (no projection due)
# Outer 9: completed update 141 for energy 1 (no projection due)
# Outer 9: completed update 142 for energy 11 (no projection due)
# Outer 9: completed update 143 for energy 6 (no projection due)
# Outer 9: projection applied after update 144 for energy 9 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 9: completed update 145 for energy 10 (no projection due)
# Outer 9: completed update 146 for energy 0 (no projection due)
# Outer 9: completed update 147 for energy 3 (no projection due)
# Outer 9: completed update 148 for energy 12 (no projection due)
# Outer 9: completed update 149 for energy 2 (no projection due)
# Outer 9: projection applied after update 150 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# --- 399.25 seconds ---
# Multi-energy multimode Phase Retrieval Done!

# %%
import interactive
cimshow(np.abs(interactive.reconstruct(fields[:,:,:])))
# Out:
# interactive(children=(FloatRangeSlider(value=(0.00015092956365876377, 0.8976318713225079), description='contra…
# interactive(children=(IntSlider(value=0, description='nr', max=14), Output()), _dom_classes=('widget-interact'…
# (<Figure size 700x700 with 1 Axes>, <Axes: >)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cimshow(components['mode_components'][0]['spectral_spatial_map'])
# Out:
# interactive(children=(FloatRangeSlider(value=(-16.01576793932037, 16.03435479808726), description='contrast', …
# (<Figure size 700x700 with 1 Axes>, <Axes: >)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
components.keys()
# Out:
# dict_keys(['projection_model', 'Nmodes', 'mode_components', 'final_fourier_constraint_applied'])

# %%
components
# Out:
# {'projection_model': 'rank1_spectral',
#  'Nmodes': 3,
#  'mode_components': [{'projection_model': 'rank1_spectral',
#    'static_log_object': array([[4.22527525-2.46572643j, 4.51742956-3.72027425j,
#            4.5868595 +2.2513354j , ..., 4.38459666+1.45726j   ,
#            4.68559101+2.37396272j, 4.38416912-5.44706511j],
#           [4.95908097+2.85373147j, 4.58892575-0.49922111j,
#            4.66002358-2.55497855j, ..., 4.52223206+1.82746179j,
#            4.55825672-0.56471032j, 4.51792276-5.27994547j],
#           [4.64454284+0.34180508j, 4.68681334+3.89754431j,
#            4.7323694 -3.73648072j, ..., 4.67220589+0.76547893j,
#            4.44380048+4.60439696j, 4.6863826 -1.53295196j],
#            [ 3.90375449e-01+2.25960741e+00j,
#             -1.41178825e-02-5.24823273e-01j,
#             -1.82955635e-02+1.05450156e+00j, ...,
#             -2.73379897e-01-7.79341394e-01j,
#              9.72324667e-02+2.59561093e-01j,
#             -1.63859824e-01+1.60818553e+00j]]]),
#    'singular_values': array([3.37581004e+03, 5.00179266e+00, 4.23911018e-11, 4.09959072e-11,
#           3.95282978e-11, 3.82987692e-11, 3.72068400e-11, 3.66095574e-11,
#           3.58306097e-11, 3.53816007e-11, 3.51705053e-11, 3.46046182e-11,
#           3.43558092e-11, 3.38302114e-11, 1.77030609e-12]),
#    'projection_supportmask_applied': False,
#    'spectral_constraint': 'known_beta',
#    'spectrum_initial': array([ 1.10946921e-04-0.37001898j,  9.04725262e-05-0.34515079j,
#            2.49711232e-05-0.32378217j, -3.09383295e-04-0.29934156j,
#            4.07295042e-05-0.23082812j, -5.08769507e-05-0.15315905j,
#           -7.40180644e-04-0.03917334j, -3.87236143e-04+0.04733712j,
#            1.70995301e-04+0.11878739j,  2.48733922e-04+0.15586939j,
#            2.38036174e-04+0.1905302j ,  1.83581482e-04+0.26014609j,
#            1.44007833e-04+0.30821222j,  1.20987432e-04+0.33617279j,
#            1.14214814e-04+0.3443988j ]),
#    'spectrum_constrained': array([-1.13011831e-04-0.37001898j, -1.13011831e-04-0.34515079j,
#           -1.40980614e-04-0.32378217j, -3.24428906e-04-0.29934156j,
#           -8.71024071e-05-0.23082812j, -1.03250402e-04-0.15315905j,
#           -4.50990342e-04-0.03917334j, -2.03360409e-04+0.04733712j,
#            1.56877098e-04+0.11878739j,  2.20084321e-04+0.15586939j,
#            2.30498755e-04+0.1905302j ,  2.32169142e-04+0.26014609j,
#            2.32169142e-04+0.30821222j,  2.32169142e-04+0.33617279j,
#            2.32169142e-04+0.3443988j ]),
#    'absorption_part': array([-1.13011831e-04, -1.13011831e-04, -1.40980614e-04, -3.24428906e-04,
#           -8.71024071e-05, -1.03250402e-04, -4.50990342e-04, -2.03360409e-04,
#            1.56877098e-04,  2.20084321e-04,  2.30498755e-04,  2.32169142e-04,
#            2.32169142e-04,  2.32169142e-04,  2.32169142e-04]),
#    'dispersion_part': array([-0.37001898, -0.34515079, -0.32378217, -0.29934156, -0.23082812,
#           -0.15315905, -0.03917334,  0.04733712,  0.11878739,  0.15586939,
#            0.1905302 ,  0.26014609,  0.30821222,  0.33617279,  0.3443988 ]),
#    'absorption_part_location': 'real'},
#   {'projection_model': 'rank1_spectral',
#    'static_log_object': array([[4.99935755-3.20601875j, 4.95195899+3.05248395j,
#            4.96419227-0.0787219j , ..., 4.75829256+1.00579713j,
#            4.64447579+0.47505747j, 4.63629548-4.06625248j],
#           [4.92627292-3.64279066j, 4.91220193+1.56109411j,
#            4.90718476+2.83933981j, ..., 4.60324511-5.13642311j,
#            4.69004293+0.93991182j, 4.90233962-6.97743267j],
#           [4.94260379+2.41858403j, 4.71134175+1.36025761j,
#            4.60713589-0.97936746j, ..., 4.92295133+1.02665736j,
#            5.01540119-5.12477166j, 4.6791878 -2.06363242j],
#           ...,
#           [4.57546436-1.69835458j, 4.86269752-0.93966384j,
#            5.00064307-2.79439444j, ..., 4.69577677-5.64471102j,
#            4.54663666-1.1534653j , 4.91007592+0.39859142j],
#           [4.8186729 +1.80500572j, 4.62500901-6.70401096j,
#            5.01977793-0.41115371j, ..., 4.73022501+0.22535273j,
#            4.47102286+4.51274248j, 4.7426713 -1.31111148j],
#           [4.86718135-4.52018544j, 4.84795877-1.08354316j,
#            4.86619811-2.645788j  , ..., 4.7576116 -4.4806728j ,
#            4.7459561 -3.07918122j, 4.49139008+0.32377207j]]),
#    'spectral_spatial_map': array([[  2.01800426+0.73323651j,  -0.23019797+0.83498112j,
#             -0.11422308+1.72677493j, ...,  -3.75536515+1.18163352j,
#              1.72330977+1.18456654j,  10.23449556+1.66362702j],
#           [  6.99075677+1.4772868j ,  -7.27037315+1.59175691j,
#             -0.39837252+1.62201066j, ...,  10.81641477-0.37297297j,
#             -5.92409006+0.96050489j,  11.4534119 +1.00589566j],
#           [  1.21562461+0.95540669j,   3.9591892 +0.79044195j,
#             -4.98960027+1.05115833j, ...,   1.95390106+0.14642132j,
#              8.5535115 +0.7968044j ,   1.89664362+0.4858888j ],
#           ...,
#           [ -3.07073422+1.6925863j ,   0.62389851+1.7039192j ,
#              4.0490595 +0.85236553j, ...,  10.58754473+0.10467831j,
#              5.41949546+1.31443196j,  -0.02768153+1.04018275j],
#           [ -4.30892016+1.67269194j,  10.72466146+1.06037727j,
#             -0.99887232+0.47197647j, ...,  -0.40911909+0.95049769j,
#            -10.94003221+1.5250279j ,  -4.84923302+0.45888987j],
#           [ 10.19069853+1.68135622j,  -0.72726809+0.34689331j,
#              3.64481851+0.95292577j, ...,   4.96675422-0.89489998j,
#              2.71829324+0.5674571j ,   0.20436271+2.49604298j]]),
#    'spectral_coefficients_initial': array([-0.00018712+0.36703464j, -0.00018759+0.3439668j ,
#           -0.00023612+0.32383355j, -0.00055226+0.30256266j,
#           -0.0001452 +0.23428204j, -0.00017454+0.15724632j,
#           -0.00077528+0.04316052j, -0.00035099-0.05025951j,
#            0.0002674 -0.12870182j,  0.00037548-0.16332497j,
#            0.00039279-0.19398083j,  0.00039435-0.25959418j,
#            0.00039343-0.30545007j,  0.0003929 -0.33162816j,
#            0.00039275-0.33914698j]),
#    'spectral_coefficients': array([-0.00019252+0.36703464j, -0.00019252+0.3439668j ,
#           -0.00024016+0.32383355j, -0.00055267+0.30256266j,
#           -0.00014838+0.23428204j, -0.00017589+0.15724632j,
#           -0.00076826+0.04316052j, -0.00034643-0.05025951j,
#            0.00026724-0.12870182j,  0.00037491-0.16332497j,
#            0.00039266-0.19398083j,  0.0003955 -0.25959418j,
#            0.0003955 -0.30545007j,  0.0003955 -0.33162816j,
#            0.0003955 -0.33914698j]),
#    'energy_dependent_log_object': array([[[-0.26951169+0.7405363j , -0.30642267-0.08465137j,
#              0.40242374-0.58398681j,  0.56826184-3.47034033j],
#            [ 0.50378222-2.37030981j,  0.53696411+2.46635467j,
#              0.54994247+0.13574835j, ..., -0.12221475-3.66850196j,
#              0.32340935+2.00951716j,  0.34567632-3.88399227j],
#            [ 0.32450408-0.41189756j,  0.26964187-1.34243446j,
#              0.35452378+1.69262362j, ...,  0.05043112-0.66260174j,
#              0.27361673-2.90058249j,  0.16553785-0.64304879j],
#            ...,
#            [ 0.57282106+1.04209967j,  0.57812581-0.2109194j ,
#              0.29067861-1.37288921j, ...,  0.03968872-3.59069246j,
#              0.44792905-1.83748568j,  0.35276389+0.0097995j ],
#            [ 0.56558424+1.46201883j,  0.36386537-3.63681721j,
#              0.15967434+0.3389512j , ...,  0.32219662+0.13912743j,
#              0.51288182+3.71088208j,  0.15371324+1.64478424j],
#            [ 0.57425733-3.45547969j,  0.11736018+0.24678798j,
#              0.32462343-1.23575232j, ..., -0.30153827-1.68481365j,
#              0.19352645-0.92167652j,  0.84660628-0.06832181j]]]),
#    'singular_values': array([3.38496328e+03, 3.55540796e-11, 3.50630054e-11, 3.41186947e-11,
#           3.28291369e-11, 3.11655753e-11, 3.03978879e-11, 3.02595144e-11,
#           2.98885594e-11, 2.96524428e-11, 2.92377699e-11, 2.88438946e-11,
#           2.81770792e-11, 2.79046128e-11, 1.46985608e-12]),
#    'projection_supportmask_applied': False,
#    'spectral_constraint': 'known_beta',
#    'spectrum_initial': array([-0.00018712+0.36703464j, -0.00018759+0.3439668j ,
#           -0.00023612+0.32383355j, -0.00055226+0.30256266j,
#           -0.0001452 +0.23428204j, -0.00017454+0.15724632j,
#           -0.00077528+0.04316052j, -0.00035099-0.05025951j,
#            0.0002674 -0.12870182j,  0.00037548-0.16332497j,
#            0.00039279-0.19398083j,  0.00039435-0.25959418j,
#            0.00039343-0.30545007j,  0.0003929 -0.33162816j,
#            0.00039275-0.33914698j]),
#    'spectrum_constrained': array([-0.00019252+0.36703464j, -0.00019252+0.3439668j ,
#           -0.00024016+0.32383355j, -0.00055267+0.30256266j,
#           -0.00014838+0.23428204j, -0.00017589+0.15724632j,
#           -0.00076826+0.04316052j, -0.00034643-0.05025951j,
#            0.00026724-0.12870182j,  0.00037491-0.16332497j,
#            0.00039266-0.19398083j,  0.0003955 -0.25959418j,
#            0.0003955 -0.30545007j,  0.0003955 -0.33162816j,
#            0.0003955 -0.33914698j]),
#    'absorption_part': array([-0.00019252, -0.00019252, -0.00024016, -0.00055267, -0.00014838,
#           -0.00017589, -0.00076826, -0.00034643,  0.00026724,  0.00037491,
#            0.00039266,  0.0003955 ,  0.0003955 ,  0.0003955 ,  0.0003955 ]),
#    'dispersion_part': array([ 0.36703464,  0.3439668 ,  0.32383355,  0.30256266,  0.23428204,
#            0.15724632,  0.04316052, -0.05025951, -0.12870182, -0.16332497,
#           -0.19398083, -0.25959418, -0.30545007, -0.33162816, -0.33914698]),
#    'absorption_part_location': 'real'}],
#  'final_fourier_constraint_applied': True}
