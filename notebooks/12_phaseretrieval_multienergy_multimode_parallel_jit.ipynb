# %% [markdown]
# # Multi-energy multimode phase retrieval parallel JIT
# Minimal use of `phase_retrieval_core_multienergy_multimode_parallel_jit.py`.

# %%
import numpy as np
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import sys, os
from os.path import join
sys.path.append("/home/user/Moritz/msc/RB2004/code/FTH-Phase_Retrieval/library")
import phase_retrieval_core_multienergy as phr_me
import phase_retrieval_core_multienergy_multimode_parallel_jit as pr

# %%
data = np.load(Path("/home/user/Moritz/msc/RB2004/data.npz"))
holograms = data["holograms"]
energy_ev = data["energy"]
mask_pixel = data["mask_pixel"]
supportmask = np.load("/home/user/Moritz/msc/RB2004/suppmask.npz.npy")

optical_constants = np.load(Path("/home/user/Moritz/msc/RB2004/data/refractive_index_constraints.npz"))
constraint_energy_ev = optical_constants["energy_ev"]
beta = optical_constants["beta"]
delta = optical_constants["delta"]

#if not np.allclose(energy_ev, constraint_energy_ev):
beta = np.interp(energy_ev, constraint_energy_ev, beta)
delta = np.interp(energy_ev, constraint_energy_ev, delta)

assert holograms.shape[0] == energy_ev.size == beta.size == delta.size
assert supportmask.shape == holograms.shape[1:]

# %%
bin_factor = 2
support_crop_pad = bin_factor
supportmask = np.load("/home/user/Moritz/msc/RB2004/suppmask.npz.npy")


def _bin_2d(array, factor, reducer="mean"):
    array = np.asarray(array)
    if array.ndim != 2:
        raise ValueError("Expected a 2D array.")
    if factor <= 0:
        raise ValueError("bin_factor must be a positive integer.")

    height, width = array.shape
    trimmed_height = height - (height % factor)
    trimmed_width = width - (width % factor)
    array = array[:trimmed_height, :trimmed_width]
    reshaped = array.reshape(
        trimmed_height // factor,
        factor,
        trimmed_width // factor,
        factor,
    )

    if reducer == "mean":
        return reshaped.mean(axis=(1, 3))
    if reducer == "max":
        return reshaped.max(axis=(1, 3))
    raise ValueError("reducer must be 'mean' or 'max'.")


def _bin_stack(stack, factor, reducer="mean"):
    stack = np.asarray(stack)
    if stack.ndim == 2:
        return _bin_2d(stack, factor, reducer=reducer)
    if stack.ndim != 3:
        raise ValueError("Expected a 2D image or 3D energy stack.")
    return np.stack([
        _bin_2d(image, factor, reducer=reducer) for image in stack
    ])


def _support_crop_slices(supportmask, pad, factor):
    supportmask = np.asarray(supportmask)
    support_pixels = np.argwhere(supportmask > 0)
    if not support_pixels.size:
        return (slice(None), slice(None))

    row_min, col_min = support_pixels.min(axis=0)
    row_max, col_max = support_pixels.max(axis=0) + 1
    height, width = supportmask.shape

    row_min = max(0, row_min - pad)
    col_min = max(0, col_min - pad)
    row_max = min(height, row_max + pad)
    col_max = min(width, col_max + pad)

    c0, c1 = (row_min + row_max) /2, (col_min + col_max) /2

    return c0, c1


c0, c1 = _support_crop_slices(
    np.load("/home/user/Moritz/msc/RB2004/suppmask.npz.npy"),
    support_crop_pad,
    bin_factor,
)


def center_and_crop(img, c0, c1, frac=0.5):
    center0, center1 = img.shape[0] // 2, img.shape[1] // 2
    shift0, shift1 = int(center0 - np.round(c0)), int(center1 - np.round(c1))
    shifted = np.roll(img, (shift0, shift1), axis=(0, 1))

    h = int(img.shape[0] * frac)//2
    w = int(img.shape[1] * frac)//2
    
    return shifted[(img.shape[0] // 2) -h:(img.shape[0] // 2) + h, (img.shape[1] // 2) - w:(img.shape[1] // 2) + w]

# %%
supportmask = center_and_crop(supportmask, c0, c1, frac=0.5)

holograms = _bin_stack(
    data["holograms"],
    bin_factor,
    reducer="mean",
)
mask_pixel = _bin_stack(
    data["mask_pixel"],
    bin_factor,
    reducer="max",
)

supportmask = (supportmask > 0).astype(supportmask.dtype)

assert holograms.shape[0] == energy_ev.size == beta.size == delta.size
assert supportmask.shape == holograms.shape[1:]
assert mask_pixel.shape == holograms.shape

# %%
from interactive import cimshow
# %matplotlib widget
cimshow(holograms)

# %%
import cupy as cp
import numpy as np

if not hasattr(cp, 'errstate'):
    cp.errstate = np.errstate

jit_status = pr.cuda_jit_status()
print(jit_status)
if jit_status.get('available'):
    pr.warm_up_jit(shape=holograms.shape[1:], modes=['ER', 'HAPRE'])
# Out:
# {'available': True, 'backend': 'cupy_nvrtc', 'import_error': None, 'device_id': 0, 'device_name': 'NVIDIA RTX 4000 Ada Generation', 'compute_capability': '89'}

# %%
recipe = {
    # Per-energy multimode update schedule.
    "inner_mode": ["HAPRE", "ER"],       # Algorithm stages at every energy.
    "inner_Nit": [700, 50],               # Iterations in each stage.
    "outer_iterations": 10,              # Number of update-plus-projection cycles.
    "warmup_mode": ["HAPRE", "ER"],      # Independent pre-coupling stages.
    "warmup_Nit": 0,                      # Zero disables warmup.
    "shuffle_energies": True,             # Randomize energy order each outer cycle.
    "random_seed": None,                  # Seed for energy-order randomization.
    "beta_zero": 0.5,                     # Beta value(s), broadcast or one per stage.
    "beta_mode": "arctan",               # Beta schedule name(s) or arrays.
    "alpha_zero": 0.0,                    # TV strength; zero disables TV.
    "alpha_mode": "const",               # Alpha schedule name(s) or arrays.
    "TV_freq": 1e9,                       # TV update interval.
    "warmup_beta_zero": None,             # None inherits the inner setting.
    "warmup_beta_mode": None,             # None inherits the inner setting.
    "warmup_alpha_zero": None,            # None inherits the inner setting.
    "warmup_alpha_mode": None,            # None inherits the inner setting.
    "warmup_TV_freq": None,               # None inherits the inner setting.
    "plot_every": 1e9,                    # Error sampling/plot interval.
    "average_img": 1,                     # Number of best late iterates to average.
    "Fourier_last": True,                 # Finish each stage with its Fourier constraint.
    "final_fourier_constraint": True,     # Enforce measured summed modal intensity at the end.
    "hologram_intensity_cutoff_vmin": -1, # Percentile baseline subtraction.
    # Cross-energy projection applied independently to every mode.
    "projection_model": "rank1_spectral",           # "none", "svd", or "rank1_spectral".
    "rank": 1,                            # SVD residual rank.
    "projection_every": 6,                # Projection interval in outer cycles.
    "projection_relaxation": 1.0,         # Projection blending fraction.
    "projection_constraints_inside_support_only": False, # If True, apply joint projections only inside supportmask.
    "projection_start": 0,                # First cycle eligible for projection.
    "projection_static_mode": "mean",    # "mean", "first", or "none".
    "energy_weights": None,               # Positive weight per energy.
    "log_floor": 1e-12,                   # Magnitude floor before complex log.
    "spectral_constraint": "known_beta",       # Rank-one spectrum: free, KK, or known-beta modes.
    "energy_values": None,                # Strictly increasing energies for KK constraints.
    "known_beta_spectrum": beta,          # Known absorption-like spectrum.
    "known_delta_spectrum": None,         # Optional known dispersion-like spectrum.
    "absorption_part": "real",           # Absorption location in the complex coefficient.
    "kk_sign": 1.0,                       # KK sign convention.
    "kk_subtract_baseline": True,         # Remove endpoint baseline before KK.
    "kk_normalize_input": False,          # Normalize absorption before KK.
    "known_beta_normalization": "none",  # none, maxabs, l2, or std.
    "fit_known_beta_scale": True,         # Fit known-spectrum scale.
    "fit_known_beta_offset": True,        # Fit known-spectrum offset.
    # Shared Richardson-Lucy controls.
    "RL_it": 0,                           # Partial-coherence iterations.
    "RL_freq": 1e9,                       # Partial-coherence update interval.
    # Multimode-only controls.
    "Nmodes": 1,                          # Number of mutually incoherent modes per energy.
    "mode_initialization_seed": 0,        # Seed used to break initial modal degeneracy.
}

fields, components, bsmasks, errors = (
    pr.multi_energy_phase_retrieval_algorithm(
        holograms,
        mask_pixel,
        supportmask,
        multi_energy_recipe=recipe,
    )
)
# Out:
# Outer 0: completed update 1 for energy 2 (no projection due)
# Outer 0: completed update 2 for energy 5 (no projection due)
# Outer 0: completed update 3 for energy 6 (no projection due)
# Outer 0: completed update 4 for energy 8 (no projection due)
# Outer 0: completed update 5 for energy 12 (no projection due)
# Outer 0: projection applied after update 6 for energy 3 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 0: completed update 7 for energy 14 (no projection due)
# Outer 0: completed update 8 for energy 4 (no projection due)
# Outer 0: completed update 9 for energy 13 (no projection due)
# Outer 0: completed update 10 for energy 0 (no projection due)
# Outer 0: completed update 11 for energy 9 (no projection due)
# Outer 0: projection applied after update 12 for energy 11 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 0: completed update 13 for energy 1 (no projection due)
# Outer 0: completed update 14 for energy 10 (no projection due)
# Outer 0: completed update 15 for energy 7 (no projection due)
# Outer 1: completed update 16 for energy 12 (no projection due)
# Outer 1: completed update 17 for energy 4 (no projection due)
# Outer 1: projection applied after update 18 for energy 14 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 1: completed update 19 for energy 1 (no projection due)
# Outer 1: completed update 20 for energy 11 (no projection due)
# Outer 1: completed update 21 for energy 13 (no projection due)
# Outer 1: completed update 22 for energy 10 (no projection due)
# Outer 1: completed update 23 for energy 9 (no projection due)
# Outer 1: projection applied after update 24 for energy 3 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 1: completed update 25 for energy 0 (no projection due)
# Outer 1: completed update 26 for energy 2 (no projection due)
# Outer 1: completed update 27 for energy 6 (no projection due)
# Outer 1: completed update 28 for energy 7 (no projection due)
# Outer 1: completed update 29 for energy 5 (no projection due)
# Outer 1: projection applied after update 30 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 2: completed update 31 for energy 10 (no projection due)
# Outer 2: completed update 32 for energy 11 (no projection due)
# Outer 2: completed update 33 for energy 13 (no projection due)
# Outer 2: completed update 34 for energy 8 (no projection due)
# Outer 2: completed update 35 for energy 5 (no projection due)
# Outer 2: projection applied after update 36 for energy 0 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 2: completed update 37 for energy 3 (no projection due)
# Outer 2: completed update 38 for energy 6 (no projection due)
# Outer 2: completed update 39 for energy 7 (no projection due)
# Outer 2: completed update 40 for energy 4 (no projection due)
# Outer 2: completed update 41 for energy 9 (no projection due)
# Outer 2: projection applied after update 42 for energy 12 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 2: completed update 43 for energy 1 (no projection due)
# Outer 2: completed update 44 for energy 14 (no projection due)
# Outer 2: completed update 45 for energy 2 (no projection due)
# Outer 3: completed update 46 for energy 9 (no projection due)
# Outer 3: completed update 47 for energy 4 (no projection due)
# Outer 3: projection applied after update 48 for energy 7 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 3: completed update 49 for energy 14 (no projection due)
# Outer 3: completed update 50 for energy 8 (no projection due)
# Outer 3: completed update 51 for energy 10 (no projection due)
# Outer 3: completed update 52 for energy 1 (no projection due)
# Outer 3: completed update 53 for energy 5 (no projection due)
# Outer 3: projection applied after update 54 for energy 12 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 3: completed update 55 for energy 6 (no projection due)
# Outer 3: completed update 56 for energy 0 (no projection due)
# Outer 3: completed update 57 for energy 13 (no projection due)
# Outer 3: completed update 58 for energy 11 (no projection due)
# Outer 3: completed update 59 for energy 3 (no projection due)
# Outer 3: projection applied after update 60 for energy 2 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 4: completed update 61 for energy 8 (no projection due)
# Outer 4: completed update 62 for energy 1 (no projection due)
# Outer 4: completed update 63 for energy 3 (no projection due)
# Outer 4: completed update 64 for energy 13 (no projection due)
# Outer 4: completed update 65 for energy 0 (no projection due)
# Outer 4: projection applied after update 66 for energy 12 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 4: completed update 67 for energy 4 (no projection due)
# Outer 4: completed update 68 for energy 6 (no projection due)
# Outer 4: completed update 69 for energy 2 (no projection due)
# Outer 4: completed update 70 for energy 10 (no projection due)
# Outer 4: completed update 71 for energy 7 (no projection due)
# Outer 4: projection applied after update 72 for energy 14 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 4: completed update 73 for energy 9 (no projection due)
# Outer 4: completed update 74 for energy 11 (no projection due)
# Outer 4: completed update 75 for energy 5 (no projection due)
# Outer 5: completed update 76 for energy 3 (no projection due)
# Outer 5: completed update 77 for energy 0 (no projection due)
# Outer 5: projection applied after update 78 for energy 11 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 5: completed update 79 for energy 10 (no projection due)
# Outer 5: completed update 80 for energy 7 (no projection due)
# Outer 5: completed update 81 for energy 8 (no projection due)
# Outer 5: completed update 82 for energy 5 (no projection due)
# Outer 5: completed update 83 for energy 14 (no projection due)
# Outer 5: projection applied after update 84 for energy 2 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 5: completed update 85 for energy 12 (no projection due)
# Outer 5: completed update 86 for energy 1 (no projection due)
# Outer 5: completed update 87 for energy 9 (no projection due)
# Outer 5: completed update 88 for energy 6 (no projection due)
# Outer 5: completed update 89 for energy 4 (no projection due)
# Outer 5: projection applied after update 90 for energy 13 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 6: completed update 91 for energy 14 (no projection due)
# Outer 6: completed update 92 for energy 2 (no projection due)
# Outer 6: completed update 93 for energy 4 (no projection due)
# Outer 6: completed update 94 for energy 6 (no projection due)
# Outer 6: completed update 95 for energy 5 (no projection due)
# Outer 6: projection applied after update 96 for energy 13 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 6: completed update 97 for energy 10 (no projection due)
# Outer 6: completed update 98 for energy 9 (no projection due)
# Outer 6: completed update 99 for energy 7 (no projection due)
# Outer 6: completed update 100 for energy 12 (no projection due)
# Outer 6: completed update 101 for energy 11 (no projection due)
# Outer 6: projection applied after update 102 for energy 3 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 6: completed update 103 for energy 1 (no projection due)
# Outer 6: completed update 104 for energy 8 (no projection due)
# Outer 6: completed update 105 for energy 0 (no projection due)
# Outer 7: completed update 106 for energy 2 (no projection due)
# Outer 7: completed update 107 for energy 4 (no projection due)
# Outer 7: projection applied after update 108 for energy 0 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 7: completed update 109 for energy 13 (no projection due)
# Outer 7: completed update 110 for energy 11 (no projection due)
# Outer 7: completed update 111 for energy 9 (no projection due)
# Outer 7: completed update 112 for energy 5 (no projection due)
# Outer 7: completed update 113 for energy 1 (no projection due)
# Outer 7: projection applied after update 114 for energy 8 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 7: completed update 115 for energy 7 (no projection due)
# Outer 7: completed update 116 for energy 12 (no projection due)
# Outer 7: completed update 117 for energy 6 (no projection due)
# Outer 7: completed update 118 for energy 10 (no projection due)
# Outer 7: completed update 119 for energy 3 (no projection due)
# Outer 7: projection applied after update 120 for energy 14 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 8: completed update 121 for energy 2 (no projection due)
# Outer 8: completed update 122 for energy 4 (no projection due)
# Outer 8: completed update 123 for energy 8 (no projection due)
# Outer 8: completed update 124 for energy 13 (no projection due)
# Outer 8: completed update 125 for energy 6 (no projection due)
# Outer 8: projection applied after update 126 for energy 12 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 8: completed update 127 for energy 9 (no projection due)
# Outer 8: completed update 128 for energy 5 (no projection due)
# Outer 8: completed update 129 for energy 7 (no projection due)
# Outer 8: completed update 130 for energy 14 (no projection due)
# Outer 8: completed update 131 for energy 3 (no projection due)
# Outer 8: projection applied after update 132 for energy 1 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 8: completed update 133 for energy 0 (no projection due)
# Outer 8: completed update 134 for energy 11 (no projection due)
# Outer 8: completed update 135 for energy 10 (no projection due)
# Outer 9: completed update 136 for energy 7 (no projection due)
# Outer 9: completed update 137 for energy 5 (no projection due)
# Outer 9: projection applied after update 138 for energy 14 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 9: completed update 139 for energy 1 (no projection due)
# Outer 9: completed update 140 for energy 2 (no projection due)
# Outer 9: completed update 141 for energy 12 (no projection due)
# Outer 9: completed update 142 for energy 3 (no projection due)
# Outer 9: completed update 143 for energy 10 (no projection due)
# Outer 9: projection applied after update 144 for energy 4 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# Outer 9: completed update 145 for energy 8 (no projection due)
# Outer 9: completed update 146 for energy 6 (no projection due)
# Outer 9: completed update 147 for energy 0 (no projection due)
# Outer 9: completed update 148 for energy 13 (no projection due)
# Outer 9: completed update 149 for energy 9 (no projection due)
# Outer 9: projection applied after update 150 for energy 11 - model=rank1_spectral, Nmodes=1, rank=1, spectral_constraint=known_beta
# --- 1308.92 seconds ---
# Multi-energy multimode Phase Retrieval Done!

# %%
from interactive import cimshow
cimshow(np.abs(interactive.reconstruct(fields)))
# Out:
# interactive(children=(FloatRangeSlider(value=(6.514746832907176e-05, 0.724735196500685), description='contrast…
# interactive(children=(IntSlider(value=0, description='nr', max=14), Output()), _dom_classes=('widget-interact'…
# (<Figure size 700x700 with 1 Axes>, <Axes: >)

# %%
components.keys()
# Out:
# dict_keys(['projection_model', 'Nmodes', 'mode_components', 'static_log_object', 'spectral_spatial_map', 'spectral_coefficients_initial', 'spectral_coefficients', 'energy_dependent_log_object', 'singular_values', 'projection_supportmask_applied', 'spectral_constraint', 'spectrum_initial', 'spectrum_constrained', 'absorption_part', 'dispersion_part', 'absorption_part_location', 'final_fourier_constraint_applied'])

# %%
components
